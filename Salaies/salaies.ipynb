# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
import plotly.io as pio 
import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/kaggle/input/salaries/salaries.csv")
df
# Out:
#         work_year experience_level employment_type                  job_title  \
# 0            2025               MI              FT             Data Scientist
# 1            2025               MI              FT             Data Scientist
# 2            2025               SE              FT       Data Product Manager
# 3            2025               SE              FT       Data Product Manager
# 4            2025               SE              FT  Machine Learning Engineer
# ...           ...              ...             ...                        ...
# 136752       2020               SE              FT             Data Scientist
# 136753       2021               MI              FT   Principal Data Scientist
# 136754       2020               EN              FT             Data Scientist
# 136755       2020               EN              CT      Business Data Analyst
# 136756       2021               SE              FT             Data Scientist
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136757 entries, 0 to 136756
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           136757 non-null  int64
#  1   experience_level    136757 non-null  object
#  2   employment_type     136757 non-null  object
#  3   job_title           136757 non-null  object
#  4   salary              136757 non-null  int64
#  5   salary_currency     136757 non-null  object
#  6   salary_in_usd       136757 non-null  int64
#  7   employee_residence  136757 non-null  object
#  8   remote_ratio        136757 non-null  int64
#  9   company_location    136757 non-null  object
#  10  company_size        136757 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 11.5+ MB

# %%
df.duplicated().sum()
# Out:
# 70694

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  66063.000000  6.606300e+04   66063.000000  66063.000000
# mean    2024.374294  1.620428e+05  151148.848084     24.672661
# std        0.730968  2.953007e+05   77438.922472     42.970711
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2024.000000  9.640000e+04   96000.000000      0.000000
# 50%     2024.000000  1.398000e+05  138900.000000      0.000000
# 75%     2025.000000  1.920000e+05  190067.500000      0.000000
# max     2025.000000  3.040000e+07  800000.000000    100.000000

# %%
cols = ['work_year' , 'salary' , 'salary_in_usd' , 'remote_ratio']

plt.figure(figsize=(10,8))
for i ,col in enumerate(cols , 1):
    plt.subplot(2,2 , i)
    sns.boxplot(data=df , x=col)
    plt.title(f'boxplot of {col}')
    plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df , x='salary' , kde=True , bins=30)
plt.show()

# %%
df.describe(include='O')
# Out:
#        experience_level employment_type       job_title salary_currency  \
# count             66063           66063           66063           66063
# unique                4               4             398              26
# top                  SE              FT  Data Scientist             USD
# freq              34743           65382            6779           60623
#
#        employee_residence company_location company_size
# count               66063            66063        66063
# unique                102               95            3
# top                    US               US            M
# freq                55377            55439        64319

# %%
df
# Out:
#         work_year experience_level employment_type                  job_title  \
# 0            2025               MI              FT             Data Scientist
# 1            2025               MI              FT             Data Scientist
# 2            2025               SE              FT       Data Product Manager
# 3            2025               SE              FT       Data Product Manager
# 4            2025               SE              FT  Machine Learning Engineer
# ...           ...              ...             ...                        ...
# 136752       2020               SE              FT             Data Scientist
# 136753       2021               MI              FT   Principal Data Scientist
# 136754       2020               EN              FT             Data Scientist
# 136755       2020               EN              CT      Business Data Analyst
# 136756       2021               SE              FT             Data Scientist
#
# ...

# %%
df['work_year'].value_counts()
# Out:
# work_year
# 2025    32434
# 2024    27689
# 2023     4537
# 2022     1114
# 2021      214
# 2020       75
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df , x='work_year' , y='salary' , edgecolor='black')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.barplot(data=df , x='salary_currency' , y='salary' , estimator=sum , edgecolor='black' , color='#cc8931')
plt.show()

# %%
df[df['work_year'].isin([2023 , 2024 , 2025])]['company_size'].head(50)
# Out:
# 0     M
# 1     M
# 2     M
# 3     M
# 4     M
# 5     M
# 6     M
# 7     M
# 8     M
# 9     M
# 10    M
# 11    M
# 12    M
# 13    M
# 14    M
# 15    M
# 16    M
# 17    M
# 18    M
# 19    M
# 20    M
# 21    M
# 22    M
# 23    M
# 24    M
# 26    M
# 27    M
# 28    M
# 29    M
# 30    M
# 31    M
# 32    M
# 33    M
# 34    M
# 35    M
# 36    M
# 37    M
# 38    M
# 39    M
# 40    M
# 41    M
# 42    M
# 43    M
# 44    M
# 45    M
# 46    M
# 47    M
# 48    M
# 49    M
# 50    M
# Name: company_size, dtype: object

# %%
df.pivot_table(index='work_year' , values='salary' , aggfunc='mean').reset_index()
# Out:
#    work_year         salary
# 0       2020  356637.453333
# 1       2021  567391.383178
# 2       2022  180859.720826
# 3       2023  160804.466828
# 4       2024  156118.087291
# 5       2025  163503.196060

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df , x='company_size' , y='salary'  , edgecolor='black')
plt.show()

# %%
df[df['company_size'] == 'M'][['employment_type' , 'experience_level']].head(20)
# Out:
#    employment_type experience_level
# 0               FT               MI
# 1               FT               MI
# 2               FT               SE
# 3               FT               SE
# 4               FT               SE
# 5               FT               SE
# 6               FT               SE
# 7               FT               SE
# 8               FT               SE
# 9               FT               SE
# 10              FT               SE
# 11              FT               SE
# 12              FT               SE
# 13              FT               SE
# 14              FT               SE
# 15              FT               SE
# 16              FT               MI
# 17              FT               MI
# 18              FT               SE
# 19              FT               SE

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df , x='experience_level' , y='salary'  , edgecolor='black' , color='#34ebd2')
plt.show()

# %%
df[df['experience_level'] == 'EN' ] ['employment_type'].head(20)
# Out:
# 68     FT
# 69     FT
# 72     FT
# 88     FT
# 89     FT
# 100    FT
# 101    FT
# 102    FT
# 103    FT
# 196    FT
# 197    FT
# 198    FT
# 199    FT
# 214    FT
# 215    FT
# 216    FT
# 217    FT
# 230    FT
# 231    FT
# 236    FT
# Name: employment_type, dtype: object

# %%
df.pivot_table(index='company_location' , values='salary_in_usd'  , aggfunc='mean').reset_index()
# Out:
#    company_location  salary_in_usd
# 0                AD   50745.000000
# 1                AE   88333.333333
# 2                AM   56409.428571
# 3                AR   78601.781250
# 4                AS   38763.250000
# ..              ...            ...
# 90               VE  192500.000000
# 91               VN   68000.000000
# 92               XK   41052.000000
# 93               ZA   61155.928571
# 94               ZM   60000.000000
#
# [95 rows x 2 columns]

# %%
df
# Out:
#         work_year experience_level employment_type                  job_title  \
# 0            2025               MI              FT             Data Scientist
# 1            2025               MI              FT             Data Scientist
# 2            2025               SE              FT       Data Product Manager
# 3            2025               SE              FT       Data Product Manager
# 4            2025               SE              FT  Machine Learning Engineer
# ...           ...              ...             ...                        ...
# 136752       2020               SE              FT             Data Scientist
# 136753       2021               MI              FT   Principal Data Scientist
# 136754       2020               EN              FT             Data Scientist
# 136755       2020               EN              CT      Business Data Analyst
# 136756       2021               SE              FT             Data Scientist
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df , x='remote_ratio' , y='salary'  , edgecolor='black' , color='#34ebd2')
plt.show()

# %%
df['experience_level'].value_counts()
# Out:
# experience_level
# SE    34743
# MI    21367
# EN     7542
# EX     2411
# Name: count, dtype: int64

# %%
pio.renderers.default = 'iframe_connected'
fig = px.pie(df , names='experience_level' , values='salary' )
fig.update_traces(textinfo='percent+label')
fig.update_layout(
    width=1000,
    height=600
)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="1020px"
#     height="620"
#     src="iframe_figures/figure_24.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df , x='employment_type' , y='salary'  , edgecolor='black' , color='#34ebd2' )
plt.show()

# %%
df
# Out:
#         work_year experience_level employment_type                  job_title  \
# 0            2025               MI              FT             Data Scientist
# 1            2025               MI              FT             Data Scientist
# 2            2025               SE              FT       Data Product Manager
# 3            2025               SE              FT       Data Product Manager
# 4            2025               SE              FT  Machine Learning Engineer
# ...           ...              ...             ...                        ...
# 136752       2020               SE              FT             Data Scientist
# 136753       2021               MI              FT   Principal Data Scientist
# 136754       2020               EN              FT             Data Scientist
# 136755       2020               EN              CT      Business Data Analyst
# 136756       2021               SE              FT             Data Scientist
#
# ...

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Data Scientist                  6779
# Data Engineer                   6653
# Data Analyst                    6031
# Software Engineer               4564
# Engineer                        4045
#                                 ...
# Controls Engineer                  1
# Business Development Manager       1
# Quant Trader                       1
# Lead AI Engineer                   1
# LLM Engineer                       1
# Name: count, Length: 398, dtype: int64

# %%
df2 = df[df['work_year'] == 2021 ]
df2
# Out:
#         work_year experience_level employment_type  \
# 131456       2021               SE              FT
# 132113       2021               MI              PT
# 132733       2021               SE              FL
# 133826       2021               MI              FT
# 134167       2021               MI              FT
# ...           ...              ...             ...
# 136749       2021               MI              FT
# 136750       2021               MI              FT
# 136751       2021               SE              FT
# 136753       2021               MI              FT
# 136756       2021               SE              FT
#
#                                  job_title   salary salary_currency  \
# 131456     Staff Machine Learning Engineer   185000             USD
# 132113               Business Data Analyst    56000             USD
# 132733          Machine Learning Developer    60000             USD
# 133826                      Data Scientist   150000             USD
# ...

# %%
df2['job_title'].value_counts()
# Out:
# job_title
# Data Scientist                              58
# Data Engineer                               36
# Machine Learning Engineer                   22
# Data Analyst                                20
# Research Scientist                          10
# Principal Data Scientist                     5
# BI Data Analyst                              4
# Big Data Engineer                            4
# Data Analytics Engineer                      3
# Data Analytics Manager                       3
# Data Architect                               3
# Machine Learning Scientist                   3
# Computer Vision Engineer                     3
# Lead Data Engineer                           3
# Head of Data                                 3
# Computer Vision Software Engineer            3
# AI Scientist                                 3
# Machine Learning Developer                   3
# Cloud Data Engineer                          2
# Applied Machine Learning Scientist           2
# ...

# %%
df2[df2['job_title'] == 'Data Scientist']['salary'].mean()
# Out:
# 1010268.6206896552

# %%
df['salary_currency'].value_counts()
# Out:
# salary_currency
# USD    60623
# GBP     2504
# EUR     2034
# CAD      487
# INR      127
# PLN       86
# CHF       36
# AUD       29
# PHP       29
# BRL       20
# SGD       16
# TWD       13
# JPY       13
# HUF        8
# NOK        5
# MXN        5
# CZK        5
# ZAR        5
# DKK        5
# TRY        4
# ILS        3
# THB        2
# SEK        1
# NZD        1
# HKD        1
# CLP        1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df2 , x='salary_currency' , y='salary' , estimator=sum , edgecolor='black' , color='#9b31cc')
plt.show()

# %%
df3 = df[df['work_year'] == 2020].head(25)
df3
# Out:
#         work_year experience_level employment_type  \
# 129421       2020               EN              FT
# 129624       2020               EN              CT
# 131457       2020               SE              FT
# 131934       2020               EN              FT
# 131966       2020               EX              FT
# 132826       2020               MI              CT
# 133234       2020               EX              FT
# 135156       2020               MI              FT
# 136158       2020               EN              FT
# 136183       2020               EN              FT
# 136439       2020               SE              FT
# 136465       2020               EN              FT
# 136474       2020               MI              FT
# 136523       2020               MI              FT
# 136531       2020               EN              FT
# 136534       2020               SE              FT
# 136539       2020               MI              FT
# ...

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df3 , x='remote_ratio' , y='salary'  , edgecolor='black' , color='#34ebd2')
plt.show()

# %%
pio.renderers.default = 'iframe_connected'
fig = px.pie(df3 , names='company_size' , values='salary')
fig.update_traces(textinfo='percent+label')
fig.update_layout(
    width=1000,
    height=600
)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="1020px"
#     height="620"
#     src="iframe_figures/figure_35.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plt.figure(figsize=(12,8))
sns.barplot(data=df3 , x='salary_currency' , y='salary')
plt.show()

# %%
df3['salary_currency'].value_counts()
# Out:
# salary_currency
# USD    13
# EUR    10
# CAD     2
# Name: count, dtype: int64
